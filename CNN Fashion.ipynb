# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D

from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
x_train=x_train.reshape(-1,28,28,1)/255.0
x_test=x_test.reshape(-1,28,28,1)/255.0

# %%
classes=['T-shirts/Top','Trouser','Pullover','Dress','coat','scandal','Shirt','Sneaker','Bag','Abkle Boot']

# %%
model=Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
   
    Flatten(),
    Dense(128,activation='relu'),
    
    Dense(10,activation='sigmoid')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history=model.fit(x_train,y_train,epochs=10,validation_split=0.1,batch_size=64,verbose=1)
# Out:
# Epoch 1/10
# 844/844 [==============================] - 37s 43ms/step - loss: 0.5020 - accuracy: 0.8186 - val_loss: 0.3916 - val_accuracy: 0.8618
# Epoch 2/10
# 844/844 [==============================] - 37s 44ms/step - loss: 0.3352 - accuracy: 0.8787 - val_loss: 0.3172 - val_accuracy: 0.8878
# Epoch 3/10
# 844/844 [==============================] - 41s 49ms/step - loss: 0.2868 - accuracy: 0.8944 - val_loss: 0.2952 - val_accuracy: 0.8908
# Epoch 4/10
# 844/844 [==============================] - 39s 46ms/step - loss: 0.2562 - accuracy: 0.9059 - val_loss: 0.2777 - val_accuracy: 0.8985
# Epoch 5/10
# 844/844 [==============================] - 36s 43ms/step - loss: 0.2314 - accuracy: 0.9145 - val_loss: 0.2678 - val_accuracy: 0.9025
# Epoch 6/10
# 844/844 [==============================] - 34s 41ms/step - loss: 0.2106 - accuracy: 0.9223 - val_loss: 0.2614 - val_accuracy: 0.9050
# Epoch 7/10
# ...

# %%
test_loss,test_acc=model.evaluate(x_test,y_test,verbose=1)
print(f"Accuracy: {test_acc*100:.2f}%")
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2800 - accuracy: 0.9100
# Accuracy: 91.00%

# %%
predictions=model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
idx=random.randint(0,len(x_test)-1)
plt.imshow(x_test[idx],cmap='gray')
plt.title(f"Predicted: {classes[np.argmax(predictions[idx])]}")
plt.axis('off')
plt.show()

# %%
idx=random.randint(0,len(x_test)-1)
plt.imshow(x_test[idx],cmap='gray')
plt.title(f"Predicted: {classes[np.argmax(predictions[idx])]}")
plt.axis('off')
plt.show()

# %%
idx=random.randint(0,len(x_test)-1)
plt.imshow(x_test[idx],cmap='gray')
plt.title(f"Predicted: {classes[np.argmax(predictions[idx])]}")
plt.axis('off')
plt.show()

# %%
idx=random.randint(0,len(x_test)-1)
plt.imshow(x_test[idx],cmap='gray')
plt.title(f"Predicted: {classes[np.argmax(predictions[idx])]}")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],label='Train Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'],label='Train Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
